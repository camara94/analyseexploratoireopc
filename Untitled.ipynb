# %%
from scipy import stats as st
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('my_courses.csv')

# %%
x = st.norm(3, 2).rvs(10000)
y = st.norm(5, 1).rvs(10000)

# %%
plt.scatter(x, y)

# %%
x = (x - x.min())/(x.max() - x.min())
y = (y - y.min())/(y.max() - y.min())

# %%
plt.scatter( x, y )

# %%
x
# Out:
# array([0.42346552, 0.50566607, 0.43932064, ..., 0.57375057, 0.48431148,
#        0.50149767])

# %%
x2 = st.norm( 
                3, 2 
            ).rvs( 
                1000 
            )

y2 = st.norm( 
                5, 1 
            ).rvs( 
                1000 
            )

# %%
x2 = ( x2 - x2.mean( ) ) / x2.std( )
y2 = ( y2 - y2.mean( ) ) / y2.std( )

# %%
len( x2 )
# Out:
# 1000

# %%
len( y2 )
# Out:
# 1000

# %%
plt.scatter( x2, y2 )

# %%
len(df)
# Out:
# 53
